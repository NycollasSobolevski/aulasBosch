# %% [markdown]
# ## Desafios
#
# Faça três gráficos utilizando as informações do dataset titanic.csv
#
# 1 - Com a quantidade de pessoas sobreviventes e não-sobreviventes
#
# 2 - Com a quantidade de pessoas por quantidade de parentes à bordo
#
# 3 - Com a quantidade de pessoas por idade, diferenciando as pessoas pelo sexo
#
# ![alt text](https://databootcamp.nyc3.digitaloceanspaces.com/img/desafio.jpg)
